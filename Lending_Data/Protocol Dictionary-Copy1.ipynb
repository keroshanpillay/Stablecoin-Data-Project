# %%
import pandas as pd

# convert into dataframe
#df = pd.read_excel("students.xlsx")

# convert into dictionary
#dict = df.to_dict()
#print(dict)

# %%
# -- define instances [TODO - add protocol to each name and dict]
instances = {
        'ethereum_v2': {'chain': 'Ethereum',  'version': 'V2','protocol':'Aave', 'url_plug': 'aave-v2-ethereum'},
        'polygon_v2':  {'chain': 'Polygon',   'version': 'V2', 'url_plug': 'aave-v2-polygon'}, # -- not fully synched / indexed 
        'avax_v2':     {'chain': 'Avalanche', 'version': 'V2', 'url_plug': 'aave-v2-avalanche'}, 
        'arc':         {'chain': 'Ethereum',  'version': 'V2', 'url_plug': 'aave-arc-ethereum'}, 
        'amm':         {'chain': 'Ethereum',  'version': 'V2', 'url_plug': 'aave-amm-ethereum'}, 
        'rwa':         {'chain': 'Ethereum',  'version': 'V2', 'url_plug': 'aave-rwa-ethereum'}, 
        'avax_v3':     {'chain': 'Avalanche', 'version': 'V3', 'url_plug': 'aave-v3-avalanche'},
        'polygon_v3':  {'chain': 'Polygon',   'version': 'V3', 'url_plug': 'aave-v3-polygon'}
    }

df = pd.DataFrame.from_dict(instances)
df.to_csv (r'test.csv', index = True, header=True)

# %%
df
# Out:
#                ethereum_v2       polygon_v2            avax_v2  \
# chain             Ethereum          Polygon          Avalanche
# version                 V2               V2                 V2
# protocol              Aave              NaN                NaN
# url_plug  aave-v2-ethereum  aave-v2-polygon  aave-v2-avalanche
#
#                         arc                amm                rwa  \
# chain              Ethereum           Ethereum           Ethereum
# version                  V2                 V2                 V2
# protocol                NaN                NaN                NaN
# url_plug  aave-arc-ethereum  aave-amm-ethereum  aave-rwa-ethereum
#
#                     avax_v3       polygon_v3
# chain             Avalanche          Polygon
# version                  V3               V3
# protocol                NaN              NaN
# url_plug  aave-v3-avalanche  aave-v3-polygon

# %%
df = pd.read_excel("lending_protocol_slugs.xlsx")

# convert into dictionary
df = df.set_index('Unnamed: 0')
instances = df.to_dict()
print(instances)
dict
# Out:
# {'aave_v2_ethereum': {'chain': 'Ethereum', 'version': 'V2', 'protocol': 'Aave', 'url_plug': 'aave-v2-ethereum'}, 'aave_v2_polygon': {'chain': 'Polygon', 'version': 'V2', 'protocol': 'Aave', 'url_plug': 'aave-v2-polygon'}, 'aave_v2_avalanche': {'chain': 'Avalanche', 'version': 'V2', 'protocol': 'Aave', 'url_plug': 'aave-v2-avalanche'}, 'aave_arc_ethereum': {'chain': 'Ethereum', 'version': 'V2', 'protocol': 'Aave', 'url_plug': 'aave-arc-ethereum'}, 'aave_amm_ethereum': {'chain': 'Ethereum', 'version': 'V2', 'protocol': 'Aave', 'url_plug': 'aave-amm-ethereum'}, 'aave_rwa_ethereum': {'chain': 'Ethereum', 'version': 'V2', 'protocol': 'Aave', 'url_plug': 'aave-rwa-ethereum'}, 'aave_v3_avalanche': {'chain': 'Avalanche', 'version': 'V3', 'protocol': 'Aave', 'url_plug': 'aave-v3-avalanche'}, 'aave_v3_polygon': {'chain': 'Polygon', 'version': 'V3', 'protocol': 'Aave', 'url_plug': 'aave-v3-polygon'}, 'banker_joe_avalanche': {'chain': 'Avalanche', 'version': 'V1', 'protocol': 'Banker Joe', 'url_
# ...

# %%
df.index.tolist()
# Out:
# ['chain', 'version', 'protocol', 'url_plug']

# %%
# -- define instances [TODO - add protocol to each name and dict]
instances = dict

df = pd.DataFrame.from_dict(instances)
df
# Out:
#           aave_v2_ethereum  aave_v2_polygon  aave_v2_avalanche  \
# chain             Ethereum          Polygon          Avalanche
# version                 V2               V2                 V2
# protocol              Aave             Aave               Aave
# url_plug  aave-v2-ethereum  aave-v2-polygon  aave-v2-avalanche
#
#           aave_arc_ethereum  aave_amm_ethereum  aave_rwa_ethereum  \
# chain              Ethereum           Ethereum           Ethereum
# version                  V2                 V2                 V2
# protocol               Aave               Aave               Aave
# url_plug  aave-arc-ethereum  aave-amm-ethereum  aave-rwa-ethereum
#
#           aave_v3_avalanche  aave_v3_polygon  banker_joe_avalanche  \
# chain             Avalanche          Polygon             Avalanche
# version                  V3               V3                    V1
# protocol               Aave             Aave            Banker Joe
# ...
